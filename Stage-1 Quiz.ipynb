# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Tag Along Code

# %%
Data = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG(1).csv', encoding = 'latin-1')

# %%
Data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
Data.groupby('Item')['Y2014','Y2017'].sum()
# Out:
# C:\Users\GODIAN\AppData\Local\Temp\ipykernel_6500\927349241.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Data.groupby('Item')['Y2014','Y2017'].sum()
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %%
mean = Data.mean()
# Out:
# C:\Users\GODIAN\AppData\Local\Temp\ipykernel_6500\1983447813.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean = Data.mean()

# %%
print(mean)
# Out:
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %%
Data_missing = Data.isnull().sum()

# %%
print(Data_missing)
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
Correlation = Data.corr()

# %%
print(Correlation)
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
Import_Quality = Data.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
# Out:
# C:\Users\GODIAN\AppData\Local\Temp\ipykernel_6500\1543173737.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Import_Quality = Data.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()

# %%
print(Import_Quality)
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
Data_2018 = Data.groupby('Element')['Y2018'].sum()

# %%
print(Data_2018)
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
Data_2018.rank()
# Out:
# Element
# Domestic supply quantity                  18.0
# Export Quantity                           10.0
# Fat supply quantity (g/capita/day)         2.0
# Feed                                      11.0
# Food                                      16.0
# Food supply (kcal/capita/day)             14.0
# Food supply quantity (kg/capita/yr)        7.0
# Import Quantity                           12.0
# Losses                                     9.0
# Other uses (non-food)                      8.0
# Processing                                13.0
# Production                                17.0
# Protein supply quantity (g/capita/day)     3.0
# Residuals                                  6.0
# Seed                                       5.0
# Stock Variation                            4.0
# Total Population - Both sexes             15.0
# Tourist consumption                        1.0
# Name: Y2018, dtype: float64

# %%
Data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
Data_algeria = Data.groupby('Area')['Y2018'].sum()

# %%
print(Data_algeria)
# Out:
# Area
# Algeria                         341729.98
# Angola                          235206.68
# Benin                           124960.70
# Botswana                         23129.08
# Burkina Faso                    112970.72
# Cabo Verde                       14622.60
# Cameroon                        233022.93
# Central African Republic         30101.57
# Chad                             72282.24
# Comoros                             59.84
# Congo                            42005.53
# Côte d'Ivoire                   227018.00
# Djibouti                         23718.96
# Egypt                           852652.92
# Eswatini                         55045.07
# Ethiopia                        450788.86
# Ethiopia PDR                         0.00
# Gabon                            28339.38
# Gambia                           23513.80
# Ghana                           358915.64
# Guinea                          103262.08
# Guinea-Bissau                    18997.92
# ...

# %%
Data.unique('A)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 Data.unique('Area')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
Data_2018 = Data.groupby('Element')['Area']['Y2018'].sum()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 Data_2018 = Data.groupby('Element')['Area']['Y2018'].sum()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\base.py:235, in SelectionMixin.__getitem__(self, key)
#     233 def __getitem__(self, key):
#     234     if self._selection is not None:
# --> 235         raise IndexError(f"Column(s) {self._selection} already selected")
#     237     if isinstance(key, (list, tuple, ABCSeries, ABCIndex, np.ndarray)):
#     238         if len(self.obj.columns.intersection(key)) != len(set(key)):
#
# IndexError: Column(s) Area already selected

# %%
Data_2018
# Out:
# Element                   Area
# Domestic supply quantity  Algeria                  90023.42
#                           Angola                   59590.22
#                           Benin                    31447.90
#                           Botswana                  3045.85
#                           Burkina Faso             25705.16
#                                                      ...
# Tourist consumption       Cabo Verde                   7.00
#                           Egypt                       23.00
#                           Kenya                       17.00
#                           Mauritius                   31.00
#                           Sao Tome and Principe       12.00
# Name: Y2018, Length: 803, dtype: float64
